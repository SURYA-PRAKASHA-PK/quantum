# %%
from qiskit import *

# %%
circuit2 = QuantumCircuit(3,3)

# %%
import matplotlib
# %matplotlib inline
circuit2.draw(output='mpl')

# %%
circuit2.x(0)
circuit2.barrier()
circuit2.draw(output='mpl')

# %%
circuit2.h(1)
circuit2.cx(1,2)

# %%
circuit2.draw(output='mpl')

# %%
circuit2.cx(0,1)
circuit2.h(0)
circuit2.draw(output='mpl')

# %%
circuit2.barrier()
circuit2.measure([0,1],[0,1])
circuit2.draw(output='mpl')

# %%
circuit2.barrier()
circuit2.cx(1,2)
circuit2.cz(0,2)
circuit2.draw(output='mpl')

# %%
circuit2.measure(2,2)
simulator= Aer.get_backend('qasm_simulator')
result=execute(circuit2,backend=simulator, shots= 1024).result()
counts=result.get_counts()
from qiskit.tools.visualization import plot_histogram
plot_histogram(counts)

# %%
pip install  qiskit-aer
# Out:
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.12.2-cp310-cp310-win_amd64.whl (9.6 MB)
#      ---------------------------------------- 9.6/9.6 MB 5.2 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.0 in c:\users\surya\anaconda3\lib\site-packages (from qiskit-aer) (1.10.0)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\surya\anaconda3\lib\site-packages (from qiskit-aer) (1.23.5)
# Requirement already satisfied: qiskit-terra>=0.21.0 in c:\users\surya\anaconda3\lib\site-packages (from qiskit-aer) (0.25.0)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\surya\anaconda3\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (5.1.0)
# Requirement already satisfied: psutil>=5 in c:\users\surya\anaconda3\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (5.9.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\surya\anaconda3\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (2.8.2)
# Requirement already satisfied: dill>=0.3 in c:\users\surya\anaconda3\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (0.3.6)
# Requirement already satisfied: typing-extensions in c:\users\surya\anaconda3\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (4.4.0)
# Requirement already satisfied: rustworkx>=0.13.0 in c:\users\surya\anaconda3\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (0.13.1)
# Requirement already satisfied: ply>=3.10 in c:\users\surya\anaconda3\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (3.11)
# Requirement already satisfied: sympy>=1.3 in c:\users\surya\anaconda3\lib\site-packages (from qiskit-terra>=0.21.0->qiskit-aer) (1.11.1)
# Requirement already satisfied: six>=1.5 in c:\users\surya\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-terra>=0.21.0->qiskit-aer) (1.16.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in c:\users\surya\anaconda3\lib\site-packages (from stevedore>=3.0.0->qiskit-terra>=0.21.0->qiskit-aer) (5.11.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\surya\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra>=0.21.0->qiskit-aer) (1.2.1)
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.12.2
# Note: you may need to restart the kernel to use updated packages.

# %%
print(counts)
# Out:
# {'111': 255, '100': 236, '110': 265, '101': 268}
